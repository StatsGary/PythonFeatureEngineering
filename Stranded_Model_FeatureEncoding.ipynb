# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://hutsons-hacks.info/wp-content/uploads/2021/04/LongLOSData.csv")

# %%
df
# Out:
#     stranded.label  age  care.home.referral  medicallysafe  hcop  \
# 0     Not Stranded   50                   0              0     0
# 1     Not Stranded   31                   1              0     1
# 2     Not Stranded   32                   0              1     0
# 3     Not Stranded   69                   1              1     0
# 4     Not Stranded   33                   0              0     1
# ..             ...  ...                 ...            ...   ...
# 763       Stranded   63                   0              1     0
# 764       Stranded   65                   1              0     0
# 765       Stranded   70                   0              0     0
# 766       Stranded   61                   0              1     0
# 767       Stranded   65                   0              0     1
#
#      mental_health_care  periods_of_previous_care  admit_date  \
# 0                     0                       1.0  29/12/2020
# ...

# %%
df.dropna()
# Out:
#     stranded.label  age  care.home.referral  medicallysafe  hcop  \
# 0     Not Stranded   50                   0              0     0
# 1     Not Stranded   31                   1              0     1
# 2     Not Stranded   32                   0              1     0
# 3     Not Stranded   69                   1              1     0
# 4     Not Stranded   33                   0              0     1
# ..             ...  ...                 ...            ...   ...
# 694   Not Stranded   25                   0              0     0
# 695   Not Stranded   43                   1              0     0
# 696       Stranded   80                   1              0     1
# 697       Stranded   79                   0              0     0
# 698       Stranded   28                   1              0     0
#
#      mental_health_care  periods_of_previous_care  admit_date  \
# 0                     0                       1.0  29/12/2020
# ...

# %%
df.dtypes
# Out:
# stranded.label               object
# age                           int64
# care.home.referral            int64
# medicallysafe                 int64
# hcop                          int64
# mental_health_care            int64
# periods_of_previous_care    float64
# admit_date                   object
# frailty_index                object
# dtype: object

# %%
# Select only the categorical variables
cat_df = df.select_dtypes(include=['object']).copy()

# %%
cat_df
# Out:
#     stranded.label  admit_date         frailty_index
# 0     Not Stranded  29/12/2020         No index item
# 1     Not Stranded  11/12/2020         No index item
# 2     Not Stranded  19/01/2021         No index item
# 3     Not Stranded  07/01/2021     Mobility problems
# 4     Not Stranded  15/01/2021         No index item
# ..             ...         ...                   ...
# 763       Stranded  19/12/2020   Activity Limitation
# 764       Stranded  23/12/2020  Fall patient history
# 765       Stranded  17/12/2020  Fall patient history
# 766       Stranded  26/01/2021     Mobility problems
# 767       Stranded  18/01/2021   Activity Limitation
#
# [768 rows x 3 columns]

# %%
# Label encoding
cat_df = cat_df.drop(['stranded.label', 'admit_date'], axis=1)

# %%
cat_df
# Out:
#             frailty_index
# 0           No index item
# 1           No index item
# 2           No index item
# 3       Mobility problems
# 4           No index item
# ..                    ...
# 763   Activity Limitation
# 764  Fall patient history
# 765  Fall patient history
# 766     Mobility problems
# 767   Activity Limitation
#
# [768 rows x 1 columns]

# %%
cat_df['frailty_index'] = cat_df['frailty_index'].astype('category')

# %%
cat_df.dtypes
# Out:
# frailty_index    category
# dtype: object

# %%
# Create the category encoding
cat_df['frail_cat_code'] = cat_df['frailty_index'].cat.codes

# %%
cat_df
# Out:
#             frailty_index  frail_cat_code
# 0           No index item               3
# 1           No index item               3
# 2           No index item               3
# 3       Mobility problems               2
# 4           No index item               3
# ..                    ...             ...
# 763   Activity Limitation               0
# 764  Fall patient history               1
# 765  Fall patient history               1
# 766     Mobility problems               2
# 767   Activity Limitation               0
#
# [768 rows x 2 columns]

# %%
# One hot encoding - dummy variable encoding
dummies = pd.get_dummies(cat_df, columns=['frailty_index'])
dummies
# Out:
#      frail_cat_code  frailty_index_Activity Limitation  \
# 0                 3                                  0
# 1                 3                                  0
# 2                 3                                  0
# 3                 2                                  0
# 4                 3                                  0
# ..              ...                                ...
# 763               0                                  1
# 764               1                                  0
# 765               1                                  0
# 766               2                                  0
# 767               0                                  1
#
#      frailty_index_Fall patient history  frailty_index_Mobility problems  \
# 0                                     0                                0
# 1                                     0                                0
# 2                                     0                                0
# ...

# %%
combined = pd.concat([df, dummies], axis=1)
combined
# Out:
#     stranded.label  age  care.home.referral  medicallysafe  hcop  \
# 0     Not Stranded   50                   0              0     0
# 1     Not Stranded   31                   1              0     1
# 2     Not Stranded   32                   0              1     0
# 3     Not Stranded   69                   1              1     0
# 4     Not Stranded   33                   0              0     1
# ..             ...  ...                 ...            ...   ...
# 763       Stranded   63                   0              1     0
# 764       Stranded   65                   1              0     0
# 765       Stranded   70                   0              0     0
# 766       Stranded   61                   0              1     0
# 767       Stranded   65                   0              0     1
#
#      mental_health_care  periods_of_previous_care  admit_date  \
# 0                     0                       1.0  29/12/2020
# ...

# %%
final_df = combined.drop(['admit_date', 'frailty_index', 'frail_cat_code'], axis=1)

# %%
final_df
# Out:
#     stranded.label  age  care.home.referral  medicallysafe  hcop  \
# 0     Not Stranded   50                   0              0     0
# 1     Not Stranded   31                   1              0     1
# 2     Not Stranded   32                   0              1     0
# 3     Not Stranded   69                   1              1     0
# 4     Not Stranded   33                   0              0     1
# ..             ...  ...                 ...            ...   ...
# 763       Stranded   63                   0              1     0
# 764       Stranded   65                   1              0     0
# 765       Stranded   70                   0              0     0
# 766       Stranded   61                   0              1     0
# 767       Stranded   65                   0              0     1
#
#      mental_health_care  periods_of_previous_care  \
# 0                     0                       1.0
# 1                     0                       1.0
# ...

# %%
# Create custom encodings
cat_df['frailty_index'].value_counts()
# Out:
# No index item           371
# Fall patient history    135
# Activity Limitation     132
# Mobility problems       130
# Name: frailty_index, dtype: int64

# %%
cat_df['mobility_issues'] = np.where(cat_df['frailty_index'].str.contains("Mobility problems"), 1,0)

# %%
cat_df
# Out:
#             frailty_index  frail_cat_code  mobility_issues
# 0           No index item               3                0
# 1           No index item               3                0
# 2           No index item               3                0
# 3       Mobility problems               2                1
# 4           No index item               3                0
# ..                    ...             ...              ...
# 763   Activity Limitation               0                0
# 764  Fall patient history               1                0
# 765  Fall patient history               1                0
# 766     Mobility problems               2                1
# 767   Activity Limitation               0                0
#
# [768 rows x 3 columns]

# %%
# Advanced encoding methods - scikit learn and statistical packages.
